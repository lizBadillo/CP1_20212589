# %%
wikiLink="https://es.wikipedia.org/wiki/Anexo:Pel%C3%ADculas_con_las_mayores_recaudaciones"

# %%
import html5lib

# %%
import pandas as pd

tablas=pd.read_html(wikiLink)

# %%
type(tablas)
# Out:
# list

# %%
pelTaquilla=tablas[0].copy()

# %%
pelTaquilla
# Out:
#     N.º                                           Película  \
# 0     1                                             Avatar
# 1     2                                  Avengers: Endgame
# 2     3                           Avatar: The Way of Water
# 3     4                                            Titanic
# 4     5  Star Wars: Episodio VII - El despertar de la F...
# ..  ...                                                ...
# 95   96                                    Shrek The Third
# 96   97                                               Coco
# 97   98                            Jumanji: The Next Level
# 98   99            Harry Potter y el prisionero de Azkaban
# 99  100         Piratas del Caribe: La venganza de Salazar
#
#                         Distribuidora (s) Taquilla (Estados Unidos)  \
# 0                        20th Century Fox      $785 221 649 (26,9%)
# 1     Walt Disney Studios Motion Pictures      $858 373 000 (30,7%)
# ...

# %%
#El tipo de información que proporciona la tabla
pelTaquilla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   N.º                         100 non-null    int64
#  1   Película                    100 non-null    object
#  2   Distribuidora (s)           100 non-null    object
#  3   Taquilla (Estados Unidos)   100 non-null    object
#  4   Taquilla (fuera de EE UU )  100 non-null    object
#  5   Recaudación mundial         100 non-null    object
#  6   Presupuesto                 100 non-null    object
#  7   Año de estreno              100 non-null    int64
#  8   Director (es)               100 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 7.2+ KB

# %%
#Nombre real de las columnas de la tabla
pelTaquilla.columns.to_list()
# Out:
# ['N.º',
#  'Película',
#  'Distribuidora (s)',
#  'Taquilla (Estados Unidos)',
#  'Taquilla (fuera de EE UU\xa0)',
#  'Recaudación mundial',
#  'Presupuesto',
#  'Año de estreno',
#  'Director (es)']

# %%
#Eliminando los espacios de los nombres de las columnas para poder configurarlos fácilmente
pelTaquilla.columns=pelTaquilla.columns.str.replace(' ', '')

# %%
#Nombre real actual de las columnas de la tabla
pelTaquilla.columns.to_list()
# Out:
# ['N.º',
#  'Película',
#  'Distribuidora(s)',
#  'Taquilla(EstadosUnidos)',
#  'Taquilla(fueradeEEUU\xa0)',
#  'Recaudaciónmundial',
#  'Presupuesto',
#  'Añodeestreno',
#  'Director(es)']

# %%
#Reemplazo el nombre de N. Unidos por "ranking" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'N.º':'ranking'}, inplace = True)

# %%
#Reemplazo el nombre de la taquilla fuera de Estados Unidos por "ta_NO_USA" para mayor rapidez al configurarlo
#Notamos que "\xa0" representa un espacio que no se observa a simple vista en la tabla
pelTaquilla.rename(columns = {'Taquilla(fueradeEEUU\xa0)':'ta_NO_USA'}, inplace = True)

# %%
#Reemplazo el nombre de la taquilla en Estados Unidos por "ta_USA" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'Taquilla(EstadosUnidos)':'ta_USA'}, inplace = True)

# %%
pelTaquilla
# Out:
#     ranking                                           Película  \
# 0         1                                             Avatar
# 1         2                                  Avengers: Endgame
# 2         3                           Avatar: The Way of Water
# 3         4                                            Titanic
# 4         5  Star Wars: Episodio VII - El despertar de la F...
# ..      ...                                                ...
# 95       96                                    Shrek The Third
# 96       97                                               Coco
# 97       98                            Jumanji: The Next Level
# 98       99            Harry Potter y el prisionero de Azkaban
# 99      100         Piratas del Caribe: La venganza de Salazar
#
#                          Distribuidora(s)                ta_USA  \
# 0                        20th Century Fox  $785 221 649 (26,9%)
# 1     Walt Disney Studios Motion Pictures  $858 373 000 (30,7%)
# ...

# %%
#Elimino ranking,ta_NO_USA,ta_USA usando "drop"
byeColumns=['ta_USA','ranking','ta_NO_USA']

#El resultado
pelTaquilla.drop(columns=byeColumns,inplace=True)
#Ahora
pelTaquilla
# Out:
#                                              Película  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                          Distribuidora(s) Recaudaciónmundial  \
# 0                        20th Century Fox     $2 923 706 026
# 1     Walt Disney Studios Motion Pictures     $2 799 439 100
# 2     Walt Disney Studios Motion Pictures     $2 316 962 130
# 3   20th Century Fox / Paramount Pictures     $2 263 291 560
# ...

# %%
#Reemplazo el nombre de la Recaudación mundial por "taquilla_total" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'Recaudaciónmundial':'taquilla_total'}, inplace = True)

# %%
#Reemplazo el nombre del año de estreno por "año_estreno" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'Añodeestreno':'año_estreno'}, inplace = True)

# %%
#Reemplazo el nombre de Distribuidora(s) por "emp_distri" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'Distribuidora(s)':'emp_distri'}, inplace = True)

# %%
#Reemplazo el nombre de Película por "pelicula" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'Película':'pelicula'}, inplace = True)

# %%
#Reemplazo el nombre de Presupuesto por "presupuesto" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'Presupuesto':'presupuesto'}, inplace = True)

# %%
#Reemplazo el nombre de Director(es) por "direccion" para mayor rapidez al configurarlo
pelTaquilla.rename(columns = {'Director(es)':'direccion'}, inplace = True)
#Ahora
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri  taquilla_total  \
# 0                        20th Century Fox  $2 923 706 026
# 1     Walt Disney Studios Motion Pictures  $2 799 439 100
# 2     Walt Disney Studios Motion Pictures  $2 316 962 130
# 3   20th Century Fox / Paramount Pictures  $2 263 291 560
# ...

# %%
#Identificando la celda que tiene un carácter no numérico 
pelTaquilla.taquilla_total.str.contains(pat=r'\D',
                          regex=True)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: taquilla_total, Length: 100, dtype: bool

# %%
#Separando en dos columunas para eliminar el signo de dolar y solo quedarnos con los números en la columna "taquilla_total"
pelTaquilla[['colBorrador1','taquilla_total']]=pelTaquilla.taquilla_total.str.split('$',expand=True)
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total  \
# 0                        20th Century Fox  2 923 706 026
# 1     Walt Disney Studios Motion Pictures  2 799 439 100
# 2     Walt Disney Studios Motion Pictures  2 316 962 130
# 3   20th Century Fox / Paramount Pictures  2 263 291 560
# ...

# %%
#Elimino colBorrador1 usando "drop"
byeColumns=['colBorrador1']

#El resultado
pelTaquilla.drop(columns=byeColumns,inplace=True)
#Ahora
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total  \
# 0                        20th Century Fox  2 923 706 026
# 1     Walt Disney Studios Motion Pictures  2 799 439 100
# 2     Walt Disney Studios Motion Pictures  2 316 962 130
# 3   20th Century Fox / Paramount Pictures  2 263 291 560
# ...

# %%
#Eliminando espacios en la columna "taquilla_total"
pelTaquilla.taquilla_total = pelTaquilla.taquilla_total.str.replace(' ', '')
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total  \
# 0                        20th Century Fox     2923706026
# 1     Walt Disney Studios Motion Pictures     2799439100
# 2     Walt Disney Studios Motion Pictures     2316962130
# 3   20th Century Fox / Paramount Pictures     2263291560
# ...

# %%
#Comprobando si cumple lo solicitado anteriormente en número aleatorios
pelTaquilla.taquilla_total[5:20]
# Out:
# 5        2052415039
# 6        1921847111
# 7        1671537444
# 8        1663075401
# 9        1520538536
# 10    1 516 341 399
# 11       1493491858
# 12       1450683476
# 13       1402018048
# 14       1346926083
# 15       1342359942
# 16       1334407706
# 17    1 310 466 296
# 18       1288540518
# 19       1264115964
# Name: taquilla_total, dtype: object

# %%
pelTaquilla.taquilla_total[17]
# Out:
# '1\xa0310\xa0466\xa0296'

# %%
pelTaquilla.taquilla_total = pelTaquilla.taquilla_total.str.replace('\xa0', '')

# %%
#Identificando la celda que tiene un carácter no numérico 
pelTaquilla.presupuesto.str.contains(pat=r'\D',
                          regex=True)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: presupuesto, Length: 100, dtype: bool

# %%
#Separando en dos columunas para eliminar el signo de dolar y solo quedarnos con los números en la columna "taquilla_total"
pelTaquilla[['colBorrador2','presupuesto']]=pelTaquilla.presupuesto.str.split('$',expand=True)
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total  \
# 0                        20th Century Fox     2923706026
# 1     Walt Disney Studios Motion Pictures     2799439100
# 2     Walt Disney Studios Motion Pictures     2316962130
# 3   20th Century Fox / Paramount Pictures     2263291560
# ...

# %%
#Identificando la celda que tiene símbolos
pelTaquilla.presupuesto[~pelTaquilla.presupuesto.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 0     237 000 000
# 1     356 000 000
# 3     200 000 000
# 4     306 000 000
# 5     356 000 000
#          ...
# 95    160 000 000
# 96    175 000 000
# 97    125 000 000
# 98    130 000 000
# 99    230 000 000
# Name: presupuesto, Length: 98, dtype: object

# %%
#Eliminando espacios en la columna "taquilla_total"
pelTaquilla.presupuesto = pelTaquilla.presupuesto.str.replace(' ', '')
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total          presupuesto  \
# 0                        20th Century Fox     2923706026            237000000
# 1     Walt Disney Studios Motion Pictures     2799439100            356000000
# 2     Walt Disney Studios Motion Pictures     2316962130  350000000-460000000
# ...

# %%
#Elimino colBorrador2 usando "drop"
byeColumns=['colBorrador2']

#El resultado
pelTaquilla.drop(columns=byeColumns,inplace=True)
#Ahora
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total          presupuesto  \
# 0                        20th Century Fox     2923706026            237000000
# 1     Walt Disney Studios Motion Pictures     2799439100            356000000
# 2     Walt Disney Studios Motion Pictures     2316962130  350000000-460000000
# ...

# %%
#Identificando la celda que aún tiene símbolos, modo de verificación
pelTaquilla.presupuesto[pelTaquilla.presupuesto.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 2     350000000-460000000
# 71    258000000-310000000
# Name: presupuesto, dtype: object

# %%
#Como vimos anteriormente, solo hay dos celdas que tiene símbolos: la fila 2 y 71 de la columuna presupuesto
#Como estas celdas representan un rango de valores, calculamos el promedio y lo reemplazos
pelTaquilla.loc[2,'presupuesto']='405000000'
pelTaquilla.loc[71,'presupuesto']='284000000'
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total presupuesto  \
# 0                        20th Century Fox     2923706026   237000000
# 1     Walt Disney Studios Motion Pictures     2799439100   356000000
# 2     Walt Disney Studios Motion Pictures     2316962130   405000000
# ...

# %%
#Identificando la celda que aún tiene símbolos, modo de verificación
pelTaquilla.presupuesto[pelTaquilla.presupuesto.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# Series([], Name: presupuesto, dtype: object)

# %%
#Comprobando si cumple lo solicitado anteriormente (no espacios) en número aleatorios
pelTaquilla.presupuesto[5:22]
# Out:
# 5       356000000
# 6       200000000
# 7       150000000
# 8       260000000
# 9       220000000
# 10    190 000 000
# 11      170000000
# 12    150 000 000
# 13      250000000
# 14    200 000 000
# 15    250 000 000
# 16    317 000 000
# 17    170 000 000
# 18    150 000 000
# 19    160 000 000
# 20    200 000 000
# 21    250 000 000
# Name: presupuesto, dtype: object

# %%
pelTaquilla.presupuesto[16]
# Out:
# '317\xa0000\xa0000'

# %%
pelTaquilla.presupuesto = pelTaquilla.presupuesto.str.replace('\xa0', '')

# %%
#Ahora limpiaremos las columnas con objetos
#Para ello, es necesario identificar que columna presenta un símbolo diferente a una letra o número 
pelTaquilla.emp_distri[pelTaquilla.emp_distri.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 3     20th Century Fox / Paramount Pictures
# 15                    Warner Bros. Pictures
# 25                    Warner Bros. Pictures
# 33                    Warner Bros. Pictures
# 35                    Warner Bros. Pictures
# 47                    Warner Bros. Pictures
# 49                    Warner Bros. Pictures
# 50                    Warner Bros. Pictures
# 53                    Warner Bros. Pictures
# 56                    Warner Bros. Pictures
# 58                    Warner Bros. Pictures
# 61                    Warner Bros. Pictures
# 64                    Warner Bros. Pictures
# 70                    Warner Bros. Pictures
# 75                    Warner Bros. Pictures
# 78                    Warner Bros. Pictures
# 87                    Warner Bros. Pictures
# 90                    Warner Bros. Pictures
# 91      Beijing Jingxi Culture & Tourism Co
# 94                    Warner Bros. Pictures
# 98                    Warner Bros. Pictures
# Name: emp_distri, dtype: object

# %%
#Cambiamos "/" por "y"
pelTaquilla.emp_distri = pelTaquilla.emp_distri.str.replace('/', 'y')

# %%
#Cambiaremos el nombre de una celda 
pelTaquilla.loc[91,'emp_distri']='Beijing Jingxi Culture y Tourism Co'

# %%
#Ahora tenemos:
pelTaquilla.emp_distri[pelTaquilla.emp_distri.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 15    Warner Bros. Pictures
# 25    Warner Bros. Pictures
# 33    Warner Bros. Pictures
# 35    Warner Bros. Pictures
# 47    Warner Bros. Pictures
# 49    Warner Bros. Pictures
# 50    Warner Bros. Pictures
# 53    Warner Bros. Pictures
# 56    Warner Bros. Pictures
# 58    Warner Bros. Pictures
# 61    Warner Bros. Pictures
# 64    Warner Bros. Pictures
# 70    Warner Bros. Pictures
# 75    Warner Bros. Pictures
# 78    Warner Bros. Pictures
# 87    Warner Bros. Pictures
# 90    Warner Bros. Pictures
# 94    Warner Bros. Pictures
# 98    Warner Bros. Pictures
# Name: emp_distri, dtype: object

# %%
pelTaquilla.emp_distri = pelTaquilla.emp_distri.str.replace('.','')
# Out:
# C:\Users\lizbe\AppData\Local\Temp\ipykernel_4280\1793034635.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pelTaquilla.emp_distri = pelTaquilla.emp_distri.str.replace('.','')

# %%
#Ahora tenemos
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                   Avengers: Endgame
# 2                            Avatar: The Way of Water
# 3                                             Titanic
# 4   Star Wars: Episodio VII - El despertar de la F...
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                            Jumanji: The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe: La venganza de Salazar
#
#                                emp_distri taquilla_total presupuesto  \
# 0                        20th Century Fox     2923706026   237000000
# 1     Walt Disney Studios Motion Pictures     2799439100   356000000
# 2     Walt Disney Studios Motion Pictures     2316962130   405000000
# ...

# %%
#Analizando si la columna "pelicula" contiene simbolos para ser limpiados
pelTaquilla.pelicula[pelTaquilla.pelicula.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 1                                     Avengers: Endgame
# 2                              Avatar: The Way of Water
# 4     Star Wars: Episodio VII - El despertar de la F...
# 5                                Avengers: Infinity War
# 6                               Spider-Man: No Way Home
# 11                                    Top Gun: Maverick
# 13                              Avengers: Age of Ultron
# 15    Harry Potter y las reliquias de la muerte: par...
# 16          Star Wars: Episodio VIII - Los últimos Jedi
# 17                       Jurassic World: El reino caído
# 24                           Capitán América: Civil War
# 26          El Señor de los Anillos: el retorno del Rey
# 28                            Spider-Man: Far From Home
# 30              Transformers: el lado oscuro de la luna
# 32                 Transformers: la era de la extinción
# 34     Star Wars: Episodio IX - El ascenso de Skywalker
# 38           Pirates of the Caribbean: Dead Man's Chest
# ...

# %%
#Reemplazamos ":" 
pelTaquilla.pelicula = pelTaquilla.pelicula.str.replace(':', '')

# %%
#Ahora tenemos 
pelTaquilla.pelicula[pelTaquilla.pelicula.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 4     Star Wars Episodio VII - El despertar de la Fu...
# 6                                Spider-Man No Way Home
# 16           Star Wars Episodio VIII - Los últimos Jedi
# 28                             Spider-Man Far From Home
# 34      Star Wars Episodio IX - El ascenso de Skywalker
# 38            Pirates of the Caribbean Dead Man's Chest
# 45           Star Wars Episodio I - La amenaza fantasma
# 66                          The Super Mario Bros. Movie
# 71                                         Spider-Man 3
# 74                                Spider-Man Homecoming
# 80     Star Wars Episodio lll - La venganza de los Sith
# 82                      Guardianes de la Galaxia vol. 2
# 91                                              Hi, Mom
# 92                                           Spider-Man
# Name: pelicula, dtype: object

# %%
#Reemplazamos ":"
pelTaquilla.pelicula = pelTaquilla.pelicula.str.replace('-', '')

# %%
#Ahora tenemos 
pelTaquilla.pelicula[pelTaquilla.pelicula.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 38    Pirates of the Caribbean Dead Man's Chest
# 66                  The Super Mario Bros. Movie
# 82              Guardianes de la Galaxia vol. 2
# 91                                      Hi, Mom
# Name: pelicula, dtype: object

# %%
#Reemplazamos el "."
pelTaquilla.pelicula = pelTaquilla.pelicula.str.replace('.', '')
# Out:
# C:\Users\lizbe\AppData\Local\Temp\ipykernel_4280\2271204892.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pelTaquilla.pelicula = pelTaquilla.pelicula.str.replace('.', '')

# %%
#Cambiamos el nombre de la celda en la fila 38 y columna "pelicula" por su nombre en español
pelTaquilla.loc[38,'pelicula']='Piratas del Caribe El cofre de la muerte'

# %%
#Cambiamos el nombre de la celda en la fila 91 y columna "pelicula" por su nombre sin coma
pelTaquilla.loc[91,'pelicula']='Hi Mom'

# %%
#Ahora tenemos 
pelTaquilla
# Out:
#                                              pelicula  \
# 0                                              Avatar
# 1                                    Avengers Endgame
# 2                             Avatar The Way of Water
# 3                                             Titanic
# 4   Star Wars Episodio VII  El despertar de la Fuerza
# ..                                                ...
# 95                                    Shrek The Third
# 96                                               Coco
# 97                             Jumanji The Next Level
# 98            Harry Potter y el prisionero de Azkaban
# 99          Piratas del Caribe La venganza de Salazar
#
#                                emp_distri taquilla_total presupuesto  \
# 0                        20th Century Fox     2923706026   237000000
# 1     Walt Disney Studios Motion Pictures     2799439100   356000000
# 2     Walt Disney Studios Motion Pictures     2316962130   405000000
# ...

# %%
#Comprobación minuciosa de espacios en el caso del guión para la columna "pelicula"
pelTaquilla.pelicula[4]
# Out:
# 'Star Wars Episodio VII  El despertar de la Fuerza'

# %%
#Se observa doble espacio, por lo tanto, se neceista de un reemplazo
pelTaquilla.pelicula = pelTaquilla.pelicula.str.replace('  ', ' ')

# %%
#Comprobación minuciosa de espacios en el caso del guión para la columna "pelicula"
pelTaquilla.pelicula[4]
# Out:
# 'Star Wars Episodio VII El despertar de la Fuerza'

# %%
#Analizando si la columna "direccion" contiene simbolos para ser limpiados
pelTaquilla.direccion[pelTaquilla.direccion.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 4                                    J. J. Abrams
# 12                       Chris Buck, Jennifer Lee
# 18                       Chris Buck, Jennifer Lee
# 21                                   F. Gary Gray
# 29                         Anna Boden, Ryan Fleck
# 34                                   J. J. Abrams
# 43        Pierre Coffin, Kyle Balda, Eric Guillon
# 44                   Andrew Stanton, Angus McLane
# 48                       Byron Howard, Rich Moore
# 62                    Andrew Stanton/ Lee Unkrich
# 65    Andrew Adamson/ Kelly Asbury/ Conrad Vernon
# 66                Aaron Horvath / Michael Jelenic
# 67                  Bryan Singer/ Dexter Fletcher
# 68                          Chen Kaige/ Tsui Hark
# 72                Carlos Saldhana/ Mike Thurmeier
# 76                  Steve Martino/ Mike Thurmeier
# 83                 Pete Docter/ Ronnie del Carmen
# 96                     Lee Unkrich/ Adrian Molina
# 99               Joachim Ronning / Espen Sandberg
# ...

# %%
#Al ver la lista de celdas en la columna "direccion" que contienen símbolos, se puede observar que la celda en la fila 43, contiene doble "/", por ello, reemplazamos esta celda manualmente
pelTaquilla.loc[43,'direccion']='Pierre Coffin Kyle Balda y Eric Guillo'
pelTaquilla.direccion[43]
# Out:
# 'Pierre Coffin Kyle Balda y Eric Guillo'

# %%
#Reemplazando "/" por " y"
pelTaquilla.direccion = pelTaquilla.direccion.str.replace('/', 'y')

# %%
#Reemplazando el punto por ''
pelTaquilla.direccion = pelTaquilla.direccion.str.replace('.', '')
# Out:
# C:\Users\lizbe\AppData\Local\Temp\ipykernel_4280\1862232580.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   pelTaquilla.direccion = pelTaquilla.direccion.str.replace('.', '')

# %%
#Ahora 
pelTaquilla.direccion[pelTaquilla.direccion.str.contains(pat=r'[^\w\s]',regex=True)]
# Out:
# 12        Chris Buck, Jennifer Lee
# 18        Chris Buck, Jennifer Lee
# 29          Anna Boden, Ryan Fleck
# 44    Andrew Stanton, Angus McLane
# 48        Byron Howard, Rich Moore
# Name: direccion, dtype: object

# %%
#Reemplazando "," por "y"
pelTaquilla.direccion = pelTaquilla.direccion.str.replace(',', ' y')

# %%
#Comprobación minuciosa de espacios en el caso de "/" para la columna "direccion"
pelTaquilla.direccion[95:100]
# Out:
# 95                        Chris Miller
# 96          Lee Unkrichy Adrian Molina
# 97                         Jake Kasdan
# 98                      Alfonso Cuarón
# 99    Joachim Ronning y Espen Sandberg
# Name: direccion, dtype: object

# %%
#Se observa doble espacio, por lo tanto, se neceista de un reemplazo
pelTaquilla.direccion = pelTaquilla.direccion.str.replace('  ', ' ')

# %%
#Ahora 
pelTaquilla.direccion.to_list()
# Out:
# ['James Cameron',
#  'Anthony y Joe Russo',
#  'James Cameron',
#  'James Cameron',
#  'J J Abrams',
#  'Anthony y Joe Russo',
#  'Jon Watts',
#  'Colin Trevorrow',
#  'Jon Favreau',
#  'Joss Whedon',
#  'James Wan',
#  'Joseph Kosinski',
#  'Chris Buck y Jennifer Lee',
#  'Joss Whedon',
#  'Ryan Coogler',
#  'David Yates',
#  'Rian Johnson',
#  'J\xa0A Bayona',
#  'Chris Buck y Jennifer Lee',
#  'Bill Condon',
#  'Brad Bird',
#  'F Gary Gray',
#  'Shane Black',
#  'Pierre Coffin',
#  'Anthony y Joe Russo',
#  'James Wan',
#  'Peter Jackson',
#  'Sam Mendes',
#  'Jon Watts',
#  'Anna Boden y Ryan Fleck',
#  'Michael Bay',
#  'Steven Spielberg',
#  'Michael Bay',
#  'Christopher Nolan',
#  'J J Abrams',
#  'Todd Phillips',
#  'Josh Cooley',
#  'Lee Unkrich',
#  'Gore Verbinski',
#  'Rob Minkoff',
#  'Gareth Edwards',
#  'Guy Ritchie',
#  'Rob Marshall',
#  'Pierre Coffin Kyle Balda y Eric Guillo',
#  'Andrew Stanton y Angus McLane',
#  'George Lucas',
#  'Tim Burton',
# ...

# %%
#Analizando celdas de la columna "año_estreno"
pelTaquilla.año_estreno.to_list()
# Out:
# [2009,
#  2019,
#  2022,
#  1997,
#  2015,
#  2018,
#  2021,
#  2015,
#  2019,
#  2012,
#  2015,
#  2022,
#  2019,
#  2015,
#  2018,
#  2011,
#  2017,
#  2018,
#  2013,
#  2017,
#  2018,
#  2017,
#  2013,
#  2015,
#  2016,
#  2018,
#  2003,
#  2012,
#  2019,
#  2019,
#  2011,
#  1993,
#  2014,
#  2012,
#  2019,
#  2019,
#  2019,
#  2010,
#  2006,
#  1994,
#  2016,
#  2019,
#  2011,
#  2017,
#  2016,
#  1999,
#  2010,
#  2001,
#  2016,
#  2012,
#  2008,
#  2022,
#  2017,
#  2010,
#  2013,
#  2016,
#  2014,
#  2007,
#  2013,
#  2022,
#  2002,
#  2007,
#  2003,
#  2022,
#  2009,
#  2004,
#  2023,
#  2018,
#  2021,
#  2001,
#  2005,
#  2007,
#  2009,
#  2015,
#  2017,
#  2002,
#  2012,
#  2016,
#  2016,
#  2017,
#  2005,
#  2013,
#  2017,
#  2015,
#  2022,
#  2018,
#  2017,
#  2010,
#  2009,
#  2012,
#  2017,
#  2021,
#  2002,
#  1996,
#  2016,
#  2007,
#  2017,
#  2019,
#  2004,
#  2017]

# %%
#El tipo de información que proporciona la tabla después de la limpieza
pelTaquilla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pelicula        100 non-null    object
#  1   emp_distri      100 non-null    object
#  2   taquilla_total  100 non-null    object
#  3   presupuesto     100 non-null    object
#  4   año_estreno     100 non-null    int64
#  5   direccion       100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
#Tabla final
pelTaquilla
# Out:
#                                             pelicula  \
# 0                                             Avatar
# 1                                   Avengers Endgame
# 2                            Avatar The Way of Water
# 3                                            Titanic
# 4   Star Wars Episodio VII El despertar de la Fuerza
# ..                                               ...
# 95                                   Shrek The Third
# 96                                              Coco
# 97                            Jumanji The Next Level
# 98           Harry Potter y el prisionero de Azkaban
# 99         Piratas del Caribe La venganza de Salazar
#
#                                emp_distri taquilla_total presupuesto  \
# 0                        20th Century Fox     2923706026   237000000
# 1     Walt Disney Studios Motion Pictures     2799439100   356000000
# 2     Walt Disney Studios Motion Pictures     2316962130   405000000
# ...

# %%
import os
pelTaquilla.to_csv(os.path.join("CP1","CP1_Badillo-Lizbeth_20212589.csv"),index=False)
